# %% [markdown]
# # Generate TFDS Dataset from Images

# %%
![ ! -f "pip_installed" ] && pip -q install tensorflow-datasets==4.4.0 && touch pip_installed

import tensorflow_datasets as tfds
tfds.__version__

# %%
![ ! -d "XRay_" ] &&  unzip -qq /content/drive/MyDrive/TeamSemiSuperCV/Wing/XRay_.zip

# %%
![ ! -d "Xray_Reborn" ] && tfds new Xray_Reborn && cp /content/drive/MyDrive/TeamSemiSuperCV/Wing/Xray_Reborn.py Xray_Reborn/

# %%
# !cd Xray_Reborn/ && tfds build

# %%
# !pushd /root/tensorflow_datasets/xray_reborn/ && zip -q -r /content/xray_reborn.zip * && popd 
# !cp xray_reborn.zip /content/drive/MyDrive/TeamSemiSuperCV/Wing/

# %%
from google.colab import auth
auth.authenticate_user()

# !gsutil -m cp -r /root/tensorflow_datasets/xray_reborn/ gs://simclrv2-wp/
