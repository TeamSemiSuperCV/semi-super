# %%
# !curl ipinfo.io
# Out:
# {
#   "ip": "35.223.141.169",
#   "hostname": "169.141.223.35.bc.googleusercontent.com",
#   "city": "Council Bluffs",
#   "region": "Iowa",
#   "country": "US",
#   "loc": "41.2619,-95.8608",
#   "org": "AS15169 Google LLC",
#   "postal": "51502",
#   "timezone": "America/Chicago",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# get latest version of tfds
![ ! -f "pip_installed" ] && pip install tensorflow-datasets==4.4.0
# !touch pip_installed
# Out:
# ...
#      |████████████████████████████████| 4.0 MB 5.3 MB/s
# ...
#   Attempting uninstall: tensorflow-datasets
#     Found existing installation: tensorflow-datasets 4.0.1
#     Uninstalling tensorflow-datasets-4.0.1:
#       Successfully uninstalled tensorflow-datasets-4.0.1
# ...

# %%
# !pip install tensorflow-addons
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 5.4 MB/s
# ...

# %%
# clone repository to contents/TeamSemiSuperCV
# !git clone https://github.com/TeamSemiSuperCV/semi-super.git /contents/TeamSemiSuperCV
# Out:
# Cloning into '/contents/TeamSemiSuperCV'...
# remote: Enumerating objects: 284, done.
# remote: Counting objects: 100% (284/284), done.
# remote: Compressing objects: 100% (187/187), done.
# remote: Total 284 (delta 154), reused 211 (delta 89), pack-reused 0
# Receiving objects: 100% (284/284), 171.97 MiB | 49.55 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# change dir to TeamSemiSuperCV (repo code)
import os
os.chdir('/contents/TeamSemiSuperCV')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# !git branch
# Out:
# * main

# %% [markdown]
# # Stage 2 fine-tuning is run for five times with the same settings (below ) and the average test accuracy is used for reporting.

# %%
# Run 1
model_folder = 'Stage2_AL_260_1_nvf'

ckpt_dir = 'gs://simclrv2-sb/reborn_again_500_1e4/saved_model/18500'
model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50,
          "width_multiplier": 2,
          "sk_ratio":0.0625,  
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir+'AL/260/',
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 60,
          'warmup_epochs': 0,
          'checkpoint_epochs': 10,
          "train_batch_size": 32,
          'train_split': 'train_act', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.001, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 0, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 1,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          'zero_init_logits_layer': True,
          "checkpoint": ckpt_dir} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-15 22:17:58.698113: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1115 22:18:00.306442 139756326557568 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/AL/260/xray_reborn/1.0.0
# I1115 22:18:00.707015 139756326557568 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/AL/260/xray_reborn/1.0.0)
# I1115 22:18:00.707318 139756326557568 run.py:596] # train examples: 260
# I1115 22:18:00.707576 139756326557568 run.py:597] # train_steps: 488
# I1115 22:18:00.707630 139756326557568 run.py:598] # eval examples: 524
# I1115 22:18:00.707678 139756326557568 run.py:599] # eval steps: 3
# I1115 22:18:00.734669 139756326557568 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# ...

# %%
# Run 2
model_folder = 'Stage2_AL_260_2_nvf'

ckpt_dir = 'gs://simclrv2-sb/reborn_again_500_1e4/saved_model/18500'
model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50,
          "width_multiplier": 2,
          "sk_ratio":0.0625,  
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir+'AL/260/',
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 60,
          'warmup_epochs': 0,
          'checkpoint_epochs': 10,
          "train_batch_size": 32,
          'train_split': 'train_act', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.001, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 0, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 1,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          'zero_init_logits_layer': True,
          "checkpoint": ckpt_dir} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-15 22:23:54.125748: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1115 22:23:55.606097 140479051773824 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/AL/260/xray_reborn/1.0.0
# I1115 22:23:55.962967 140479051773824 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/AL/260/xray_reborn/1.0.0)
# I1115 22:23:55.963252 140479051773824 run.py:596] # train examples: 260
# I1115 22:23:55.963501 140479051773824 run.py:597] # train_steps: 488
# I1115 22:23:55.963556 140479051773824 run.py:598] # eval examples: 524
# I1115 22:23:55.963603 140479051773824 run.py:599] # eval steps: 3
# I1115 22:23:55.988447 140479051773824 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# ...

# %%
# Run 3
model_folder = 'Stage2_AL_260_3_nvf'

ckpt_dir = 'gs://simclrv2-sb/reborn_again_500_1e4/saved_model/18500'
model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50,
          "width_multiplier": 2,
          "sk_ratio":0.0625,  
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir+'AL/260/',
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 60,
          'warmup_epochs': 0,
          'checkpoint_epochs': 10,
          "train_batch_size": 32,
          'train_split': 'train_act', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.001, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 0, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 1,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          'zero_init_logits_layer': True,
          "checkpoint": ckpt_dir} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-15 22:29:52.790962: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1115 22:29:54.280161 140178799564672 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/AL/260/xray_reborn/1.0.0
# I1115 22:29:54.595166 140178799564672 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/AL/260/xray_reborn/1.0.0)
# I1115 22:29:54.595470 140178799564672 run.py:596] # train examples: 260
# I1115 22:29:54.595718 140178799564672 run.py:597] # train_steps: 488
# I1115 22:29:54.595773 140178799564672 run.py:598] # eval examples: 524
# I1115 22:29:54.595816 140178799564672 run.py:599] # eval steps: 3
# I1115 22:29:54.620126 140178799564672 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# ...

# %%
# Run 4
model_folder = 'Stage2_AL_260_4_nvf'

ckpt_dir = 'gs://simclrv2-sb/reborn_again_500_1e4/saved_model/18500'
model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50,
          "width_multiplier": 2,
          "sk_ratio":0.0625,  
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir+'AL/260/',
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 60,
          'warmup_epochs': 0,
          'checkpoint_epochs': 10,
          "train_batch_size": 32,
          'train_split': 'train_act', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.001, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 0, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 1,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          'zero_init_logits_layer': True,
          "checkpoint": ckpt_dir} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-15 22:35:50.464108: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1115 22:35:51.910395 139856291915648 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/AL/260/xray_reborn/1.0.0
# I1115 22:35:52.279015 139856291915648 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/AL/260/xray_reborn/1.0.0)
# I1115 22:35:52.279327 139856291915648 run.py:596] # train examples: 260
# I1115 22:35:52.279580 139856291915648 run.py:597] # train_steps: 488
# I1115 22:35:52.279633 139856291915648 run.py:598] # eval examples: 524
# I1115 22:35:52.279680 139856291915648 run.py:599] # eval steps: 3
# I1115 22:35:52.307088 139856291915648 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# ...

# %%
# Run 5
model_folder = 'Stage2_AL_260_5_nvf'

ckpt_dir = 'gs://simclrv2-sb/reborn_again_500_1e4/saved_model/18500'
model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50,
          "width_multiplier": 2,
          "sk_ratio":0.0625,  
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir+'AL/260/',
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 60,
          'warmup_epochs': 0,
          'checkpoint_epochs': 10,
          "train_batch_size": 32,
          'train_split': 'train_act', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.001, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 0, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 1,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          'zero_init_logits_layer': True,
          "checkpoint": ckpt_dir} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-15 22:41:54.876075: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1115 22:41:56.952829 140477245118336 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/AL/260/xray_reborn/1.0.0
# I1115 22:41:57.301938 140477245118336 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/AL/260/xray_reborn/1.0.0)
# I1115 22:41:57.302235 140477245118336 run.py:596] # train examples: 260
# I1115 22:41:57.302480 140477245118336 run.py:597] # train_steps: 488
# I1115 22:41:57.302532 140477245118336 run.py:598] # eval examples: 524
# I1115 22:41:57.302605 140477245118336 run.py:599] # eval steps: 3
# I1115 22:41:57.327473 140477245118336 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# ...
