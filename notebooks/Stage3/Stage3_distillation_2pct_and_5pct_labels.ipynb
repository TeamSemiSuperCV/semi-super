# %%
# !curl ipinfo.io
# Out:
# {
#   "ip": "34.135.178.15",
#   "hostname": "15.178.135.34.bc.googleusercontent.com",
#   "city": "Council Bluffs",
#   "region": "Iowa",
#   "country": "US",
#   "loc": "41.2619,-95.8608",
#   "org": "AS15169 Google LLC",
#   "postal": "51502",
#   "timezone": "America/Chicago",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# get latest version of tfds
![ ! -f "pip_installed" ] && pip install tensorflow-datasets==4.4.0
# !touch pip_installed
# Out:
# Collecting tensorflow-datasets==4.4.0
#   Downloading tensorflow_datasets-4.4.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 5.4 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (0.16.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (0.3.4)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (1.4.0)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (3.17.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (4.62.3)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (21.2.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (1.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (3.10.0.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (5.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (1.15.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (2.23.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (0.12.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets==4.4.0) (2.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->tensorflow-datasets==4.4.0) (2.10)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->tensorflow-datasets==4.4.0) (3.6.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-metadata->tensorflow-datasets==4.4.0) (1.53.0)
# Installing collected packages: tensorflow-datasets
#   Attempting uninstall: tensorflow-datasets
#     Found existing installation: tensorflow-datasets 4.0.1
#     Uninstalling tensorflow-datasets-4.0.1:
#       Successfully uninstalled tensorflow-datasets-4.0.1
# Successfully installed tensorflow-datasets-4.4.0

# %%
# !pip install tensorflow-addons
# Out:
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.3 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
# clone repository to contents/TeamSemiSuperCV
# !git clone https://github.com/TeamSemiSuperCV/semi-super.git /contents/TeamSemiSuperCV
# Out:
# Cloning into '/contents/TeamSemiSuperCV'...
# remote: Enumerating objects: 299, done.
# remote: Counting objects: 100% (299/299), done.
# remote: Compressing objects: 100% (197/197), done.
# remote: Total 299 (delta 164), reused 221 (delta 94), pack-reused 0
# Receiving objects: 100% (299/299), 171.97 MiB | 49.49 MiB/s, done.
# Resolving deltas: 100% (164/164), done.

# %%
# change dir to TeamSemiSuperCV (repo code)
import os
os.chdir('/contents/TeamSemiSuperCV')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
# !git branch
# Out:
# * main

# %% [markdown]
# # Stage 3 knowledge distillation with the 2 percent labels model from Stage 2 as the teacher model.

# %%
model_folder = 'dist_nolam_1e5_2pc_rand_run2'

teacher_model_dir = 'gs://simclrv2-sb/reborn_again_2pc_1/saved_model/210'

model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50, 
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir,
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 1000,
          'checkpoint_epochs': 50,
          "train_batch_size": 128,
          'train_split': 'train', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.20, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 1e-5, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 0.5,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          "distill_mode": True,
          "teacher_model_dir": teacher_model_dir,
          "keras_resnet50": True} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-16 15:17:53.521078: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1116 15:17:54.959855 140017736750976 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/xray_reborn/1.0.0
# I1116 15:17:55.277543 140017736750976 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/xray_reborn/1.0.0)
# I1116 15:17:55.277833 140017736750976 run.py:619] # train examples: 4708
# I1116 15:17:55.278091 140017736750976 run.py:620] # train_steps: 36782
# I1116 15:17:55.278146 140017736750976 run.py:621] # eval examples: 524
# I1116 15:17:55.278215 140017736750976 run.py:622] # eval steps: 3
# I1116 15:17:55.306134 140017736750976 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# I1116 15:17:55.306438 140017736750976 tpu_strategy_util.py:61] Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.123.109.58:8470
# I1116 15:17:55.436051 140017736750976 tpu_strategy_util.py:85] Initializing the TPU system: grpc://10.123.109.58:8470
# INFO:tensorflow:Finished initializing TPU system.
# I1116 15:18:06.402914 140017736750976 tpu_strategy_util.py:146] Finished initializing TPU system.
# I1116 15:18:06.403736 140017736750976 run.py:636] Topology:
# I1116 15:18:06.403878 140017736750976 run.py:637] num_tasks: 1
# I1116 15:18:06.403954 140017736750976 run.py:638] num_tpus_per_task: 8
# INFO:tensorflow:Found TPU system:
# I1116 15:18:06.404740 140017736750976 tpu_system_metadata.py:159] Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# I1116 15:18:06.404895 140017736750976 tpu_system_metadata.py:160] *** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# I1116 15:18:06.404969 140017736750976 tpu_system_metadata.py:161] *** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# I1116 15:18:06.405046 140017736750976 tpu_system_metadata.py:163] *** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# I1116 15:18:06.405116 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# I1116 15:18:06.405400 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# I1116 15:18:06.405467 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# I1116 15:18:06.405536 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# I1116 15:18:06.405595 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# I1116 15:18:06.405661 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# I1116 15:18:06.405720 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# I1116 15:18:06.405778 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# I1116 15:18:06.405836 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# I1116 15:18:06.405892 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# I1116 15:18:06.405950 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# I1116 15:18:06.406008 140017736750976 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# I1116 15:18:15.960990 140017736750976 run.py:653] Loaded Keras ResNet50 as student model
# I1116 15:18:15.961164 140017736750976 run.py:657] Distillation mode active
# I1116 15:18:15.961238 140017736750976 run.py:658] Restoring teacher model from: gs://simclrv2-sb/reborn_again_2pc_1/saved_model/210
# W1116 15:18:16.690101 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.693837 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.696597 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.708890 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.711589 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.714157 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.716746 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.724818 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.727484 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.730256 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.732782 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.741120 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.743759 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.746324 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.749056 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134724) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.751846 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.754535 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.757098 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.765592 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.768246 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.770879 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.773468 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.776193 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.780457 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.783024 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.785813 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.788492 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.802857 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.805573 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.808241 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.820125 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.822911 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.825557 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.828165 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.832978 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.835669 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.838383 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.840965 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.843559 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.846106 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.857886 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.860595 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.869038 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.877330 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.889212 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.891805 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.894378 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.896991 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.899576 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.902511 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.905139 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.907701 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.910371 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.913030 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.915717 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.929996 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.932672 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.935334 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.938022 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.940743 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.943385 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.964667 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.967488 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.970360 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.982294 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.985159 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:16.987818 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.005209 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.007776 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.010334 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.012935 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.100783 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.105515 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.108361 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133734) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.111082 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.123160 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.125928 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.128622 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.131332 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.144493 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.147253 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.149961 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.152750 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.155453 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.158257 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.160919 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.173054 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.181644 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.188916 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.191616 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.194286 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.197043 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.199770 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.202514 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.205206 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.207798 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.210612 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.213335 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.220378 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.223201 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.225897 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.228472 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.231184 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.233735 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.236514 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.249305 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.252257 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.254922 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.257646 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.260620 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.263438 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.266194 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.268911 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.281059 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.283914 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.286734 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.289789 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.292558 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.295680 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.298377 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.301106 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.303783 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.306499 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.310099 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.318718 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.321371 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.495039 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.498024 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.516408 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.525313 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.528141 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.531006 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.533664 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.536497 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.539242 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.541861 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.544543 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.547258 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.550075 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.552765 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.555370 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.558019 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.560627 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.569302 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.571895 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.574580 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.577413 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.580111 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.582813 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.585595 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.588296 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.591195 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.615062 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.617645 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.620170 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.622874 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.625508 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.633202 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.650422 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.661675 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.665562 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.668380 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.671120 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.673717 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.676344 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.678999 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.681454 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.684013 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.703398 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.706137 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.708750 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.711424 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.741268 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.743664 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.746138 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.748728 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.751230 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.753724 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.756246 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.758660 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.761216 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.763627 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.771663 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.774223 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.776961 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.779518 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.782185 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.784771 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.796202 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.798830 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.801678 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.804403 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.807053 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.809629 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.812303 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.815102 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 15:18:17.826961 140017736750976 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# W1116 16:29:36.658106 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.677934 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.680296 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.703993 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.706640 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.709409 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.717747 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.738760 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.769314 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.771941 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.774634 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.786574 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.812641 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.815554 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.818135 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.843258 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.846170 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.871187 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.895943 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.917111 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.919863 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.922721 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.925446 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.950804 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:36.972286 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.000577 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.023650 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.060793 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.081930 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.104874 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.129764 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.155077 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.176610 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.200871 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.227505 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.249845 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.252798 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.255423 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.258063 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.279556 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.282347 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.313011 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.335157 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.360448 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.381840 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.384737 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.387423 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.412591 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.438273 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.459656 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.484864 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.510732 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.513479 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.516146 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.543525 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.569827 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134854) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.572797 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.596055 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.630421 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.641999 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.653280 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:29:37.661454 140532207044480 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# INFO:tensorflow:Waiting for new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2
# I1116 16:29:43.997564 140532207044480 checkpoint_utils.py:140] Waiting for new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2
# INFO:tensorflow:Found new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2/ckpt-37000
# I1116 16:29:44.134605 140532207044480 checkpoint_utils.py:149] Found new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2/ckpt-37000
# I1116 16:29:44.135322 140532207044480 data.py:46] Global batch size: 256
# I1116 16:29:44.135437 140532207044480 data.py:47] Per-replica batch size: 32
# I1116 16:29:44.135538 140532207044480 data.py:64] num_input_pipelines: 1
# I1116 16:29:44.135651 140532207044480 logging_logger.py:36] Constructing tf.data.Dataset xray_reborn for split test, from gs://simclrv2-sb/xray_reborn/1.0.0
# I1116 16:29:44.508449 140532207044480 run.py:449] Restoring from gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2/ckpt-37000
# I1116 16:29:46.373734 140532207044480 run.py:454] Performing eval at step 37000
# I1116 16:29:47.133519 140532207044480 tpu.py:1293] Automatic outside compilation is enabled. Ops without XLA kernels will be automatically placed on CPU.
# I1116 16:29:47.303689 140532207044480 tpu.py:1401] TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond/Identity:0' shape=(None, 224, 224, 3) dtype=float32>, <tf.Tensor 'cond/Identity_8:0' shape=(None, 2) dtype=float32>]
# I1116 16:29:48.804061 140532207044480 run.py:488] Completed eval for 1 / 3 steps
# I1116 16:29:48.806792 140532207044480 run.py:488] Completed eval for 2 / 3 steps
# I1116 16:29:48.809324 140532207044480 run.py:488] Completed eval for 3 / 3 steps
# I1116 16:29:48.809413 140532207044480 run.py:489] Finished eval for gs://simclrv2-sb/dist_nolam_1e5_2pc_rand_run2/ckpt-37000
# I1116 16:29:55.818976 140532207044480 run.py:493] Writing summaries for 37000 step
# I1116 16:29:55.823651 140532207044480 metrics.py:77] Step: [37000] eval/regularization_loss = 0.000037
# I1116 16:29:55.831362 140532207044480 metrics.py:77] Step: [37000] eval/supervised_loss = nan
# I1116 16:29:55.836552 140532207044480 metrics.py:77] Step: [37000] eval/label_top_1_accuracy = 0.975923
# I1116 16:29:55.842330 140532207044480 metrics.py:77] Step: [37000] eval/label_top_5_accuracy = 1.000000
# I1116 16:29:56.007536 140532207044480 run.py:503] {'eval/regularization_loss': 3.7348454e-05, 'eval/supervised_loss': nan, 'eval/label_top_1_accuracy': 0.97592294, 'eval/label_top_5_accuracy': 1.0, 'global_step': 37000}
# I1116 16:29:56.211647 140532207044480 run.py:667] Eval complete. Exiting...

# %% [markdown]
# # Stage 3 knowledge distillation with the 5 percent labels model from Stage 2 as the teacher model.

# %%
model_folder = 'dist_nolam_1e5_5pc_active_run2'

teacher_model_dir = 'gs://simclrv2-sb/Stage2_AL_260_3_nvf/saved_model/560'

model_dir = 'gs://simclrv2-sb/'

class simclrCommand():
  def __init__(self, model_dir, model_folder, params={}):
    #default params
    self.params = {'train_mode': "finetune", 
          "mode": "train_then_eval",    
          "resnet_depth": 50, 
          "color_jitter_strength": 0.5,
          'model_dir': model_dir+model_folder,
          "data_dir": model_dir,
          "use_tpu": True}
    # add in or change params
    if len(params) > 0:
      for k,v in params.items():
        self.params[k]=v
  def compile_command(self):
    simclr_command = ['python run.py']
    for k,v in self.params.items():
      simclr_command.append(f'--{k}={v}')
    return (" ").join(simclr_command)
  def run_command(self):
    # !{self.compile_command()}

params = {"train_epochs": 1000,
          'checkpoint_epochs': 50,
          "train_batch_size": 128,
          'train_split': 'train', 
          "image_size": 224,   
          'dataset': "xray_reborn",
          "learning_rate": 0.20, 
          "learning_rate_scaling": 'sqrt',
          'weight_decay': 1e-5, 
          "temperature": 0.1,
          "use_blur": False, 
          "area_range_min": 0.5,
          "eval_split": "validation",    
          "eval_per_loop": False,
          'fine_tune_after_block': -1,
          "distill_mode": True,
          "teacher_model_dir": teacher_model_dir,
          "keras_resnet50": True} 
slimsk2 = simclrCommand(model_dir, model_folder, params)
slimsk2.run_command()

slimsk2.params['mode'] = 'eval'
slimsk2.params['eval_split'] = 'test'

slimsk2.run_command()
# Out:
# 2021-11-16 16:30:01.946562: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# I1116 16:30:03.402253 139713704441728 dataset_info.py:358] Load dataset info from gs://simclrv2-sb/xray_reborn/1.0.0
# I1116 16:30:03.774600 139713704441728 dataset_builder.py:351] Reusing dataset xray_reborn (gs://simclrv2-sb/xray_reborn/1.0.0)
# I1116 16:30:03.774914 139713704441728 run.py:619] # train examples: 4708
# I1116 16:30:03.775219 139713704441728 run.py:620] # train_steps: 36782
# I1116 16:30:03.775277 139713704441728 run.py:621] # eval examples: 524
# I1116 16:30:03.775325 139713704441728 run.py:622] # eval steps: 3
# I1116 16:30:03.798938 139713704441728 remote.py:237] Entering into master device scope: /job:worker/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# I1116 16:30:03.799223 139713704441728 tpu_strategy_util.py:61] Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: grpc://10.123.109.58:8470
# I1116 16:30:03.931660 139713704441728 tpu_strategy_util.py:85] Initializing the TPU system: grpc://10.123.109.58:8470
# INFO:tensorflow:Finished initializing TPU system.
# I1116 16:30:18.974240 139713704441728 tpu_strategy_util.py:146] Finished initializing TPU system.
# I1116 16:30:18.975002 139713704441728 run.py:636] Topology:
# I1116 16:30:18.975118 139713704441728 run.py:637] num_tasks: 1
# I1116 16:30:18.975188 139713704441728 run.py:638] num_tpus_per_task: 8
# INFO:tensorflow:Found TPU system:
# I1116 16:30:18.975890 139713704441728 tpu_system_metadata.py:159] Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# I1116 16:30:18.975987 139713704441728 tpu_system_metadata.py:160] *** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# I1116 16:30:18.976044 139713704441728 tpu_system_metadata.py:161] *** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# I1116 16:30:18.976101 139713704441728 tpu_system_metadata.py:163] *** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# I1116 16:30:18.976149 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# I1116 16:30:18.976397 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# I1116 16:30:18.976450 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# I1116 16:30:18.976499 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# I1116 16:30:18.976548 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# I1116 16:30:18.976597 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# I1116 16:30:18.976656 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# I1116 16:30:18.976704 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# I1116 16:30:18.976752 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# I1116 16:30:18.976803 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# I1116 16:30:18.976850 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# I1116 16:30:18.976898 139713704441728 tpu_system_metadata.py:165] *** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# I1116 16:30:28.624897 139713704441728 run.py:653] Loaded Keras ResNet50 as student model
# I1116 16:30:28.625101 139713704441728 run.py:657] Distillation mode active
# I1116 16:30:28.625187 139713704441728 run.py:658] Restoring teacher model from: gs://simclrv2-sb/Stage2_AL_260_3_nvf/saved_model/560
# W1116 16:30:29.424454 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.428484 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.431308 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.443575 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.446306 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.448853 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.451434 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.459261 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.461931 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.464339 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.466707 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.474373 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.476804 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.479246 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.481868 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134724) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.484354 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.486835 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.489221 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.497100 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.499694 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.502314 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.504702 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.507375 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.511435 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.513625 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.515889 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.518219 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.531450 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.533948 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.536441 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134884) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.547524 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.549967 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.552515 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.554863 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.559553 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.562078 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.564413 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.566611 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.568969 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.571496 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.582706 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.585219 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.592975 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.600578 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.611305 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.613672 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.615971 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.618465 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.621033 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137844) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.623507 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.625864 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.628208 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.630671 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.633148 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.635471 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.648696 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.651326 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.653827 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.656484 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136324) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.659321 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.662049 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.682883 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.685629 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.688458 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.700362 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.703157 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.705730 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.723493 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.726203 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.728838 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133644) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.731647 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.825537 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.830345 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.833209 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133734) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.835932 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137034) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.847866 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.850574 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.853278 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.855942 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.869258 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.872097 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.874884 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133654) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.877711 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.880500 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.883169 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.885747 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.897702 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133464) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.906168 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.913344 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.915977 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.918694 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.921448 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.924119 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.926808 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.929486 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.932089 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.934873 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.937646 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.944752 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136894) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.947575 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.950158 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.952741 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.955333 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.957961 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.960741 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.972083 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.974709 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.977061 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135524) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.979562 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138924) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.982126 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.984468 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.986884 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:29.989312 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.000114 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.002734 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.005121 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.007612 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.010028 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.012628 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139054) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.015086 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.017425 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.019801 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.022339 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.025385 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134704) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.032803 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.035259 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.211952 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.215046 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134934) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.233991 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.243034 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.245898 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.248738 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.251405 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138124) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.254245 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135184) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.257339 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.260018 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.263009 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.265872 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.268882 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.271830 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135764) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.274678 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139534) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.278019 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.280778 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.289509 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.292126 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135204) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.294878 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.297748 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.300600 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.303459 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135504) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.306238 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.308998 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.311950 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.338833 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135304) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.342418 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134344) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.345578 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.348677 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135754) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.351683 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.360728 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.379445 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134154) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.392439 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136274) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.396963 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.400295 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.403187 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.406038 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137334) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.408842 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135354) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.411698 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.414401 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135384) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.417097 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.438886 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133484) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.441698 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136794) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.444654 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139044) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.447450 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.481963 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135254) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.484756 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.487490 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.490407 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136814) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.493047 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136144) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.495806 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133244) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.498414 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.501026 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136364) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.503757 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135094) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.506446 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133984) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.515064 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139294) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.517878 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.520630 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137024) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.523250 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.525942 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134474) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.528521 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138104) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.540593 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137774) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.543260 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138634) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.546075 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139264) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.548822 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.551492 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137114) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.554062 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137824) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.556813 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.559602 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 16:30:30.571420 139713704441728 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136614) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# ...
# W1116 17:40:43.662043 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136574) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.684610 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.687551 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.713374 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133834) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.716309 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134694) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.719197 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.727620 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138604) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.749027 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.779308 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135134) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.781645 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133784) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.783912 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.794342 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138214) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.817378 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134904) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.819929 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136964) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.822195 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137494) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.844236 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133674) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.846781 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135994) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.869589 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137744) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.893975 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138914) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.915464 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.918320 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.921297 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133224) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.924018 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135164) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.949410 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135714) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.971631 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135544) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:43.999149 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138664) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.021708 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139284) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.058687 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.083073 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.111887 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138454) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.140437 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.167436 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135444) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.189685 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.211615 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135804) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.238057 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135394) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.261406 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133434) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.264377 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.267057 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_132944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.269764 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134554) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.291500 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133234) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.294376 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136864) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.325581 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.347332 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138584) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.372226 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_139074) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.391428 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134974) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.393901 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136954) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.396264 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.419967 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136064) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.442722 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.462039 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_136944) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.484647 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138874) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.507656 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134684) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.509889 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133194) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.512275 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138404) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.535887 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_137564) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.559119 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_134854) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.561747 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_138424) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.581675 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135624) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.617225 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133314) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.629445 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_135014) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.641347 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133594) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# W1116 17:40:44.649920 140001254688640 function_deserialization.py:580] Importing a function (__inference_internal_grad_fn_133514) with ops with unsaved custom gradients. Will likely fail if a gradient is requested.
# INFO:tensorflow:Waiting for new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2
# I1116 17:40:51.153610 140001254688640 checkpoint_utils.py:140] Waiting for new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2
# INFO:tensorflow:Found new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2/ckpt-37000
# I1116 17:40:51.250817 140001254688640 checkpoint_utils.py:149] Found new checkpoint at gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2/ckpt-37000
# I1116 17:40:51.251469 140001254688640 data.py:46] Global batch size: 256
# I1116 17:40:51.251570 140001254688640 data.py:47] Per-replica batch size: 32
# I1116 17:40:51.251668 140001254688640 data.py:64] num_input_pipelines: 1
# I1116 17:40:51.251790 140001254688640 logging_logger.py:36] Constructing tf.data.Dataset xray_reborn for split test, from gs://simclrv2-sb/xray_reborn/1.0.0
# I1116 17:40:51.636310 140001254688640 run.py:449] Restoring from gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2/ckpt-37000
# I1116 17:40:53.551273 140001254688640 run.py:454] Performing eval at step 37000
# I1116 17:40:54.318808 140001254688640 tpu.py:1293] Automatic outside compilation is enabled. Ops without XLA kernels will be automatically placed on CPU.
# I1116 17:40:54.471057 140001254688640 tpu.py:1401] TPU has inputs with dynamic shapes: [<tf.Tensor 'Const:0' shape=() dtype=int32>, <tf.Tensor 'cond/Identity:0' shape=(None, 224, 224, 3) dtype=float32>, <tf.Tensor 'cond/Identity_8:0' shape=(None, 2) dtype=float32>]
# I1116 17:40:56.005861 140001254688640 run.py:488] Completed eval for 1 / 3 steps
# I1116 17:40:56.009012 140001254688640 run.py:488] Completed eval for 2 / 3 steps
# I1116 17:40:56.011719 140001254688640 run.py:488] Completed eval for 3 / 3 steps
# I1116 17:40:56.011835 140001254688640 run.py:489] Finished eval for gs://simclrv2-sb/dist_nolam_1e5_5pc_active_run2/ckpt-37000
# I1116 17:40:57.851841 140001254688640 run.py:493] Writing summaries for 37000 step
# I1116 17:40:57.858776 140001254688640 metrics.py:77] Step: [37000] eval/regularization_loss = 0.000035
# I1116 17:40:57.867000 140001254688640 metrics.py:77] Step: [37000] eval/supervised_loss = nan
# I1116 17:40:57.873135 140001254688640 metrics.py:77] Step: [37000] eval/label_top_1_accuracy = 0.980738
# I1116 17:40:57.878809 140001254688640 metrics.py:77] Step: [37000] eval/label_top_5_accuracy = 1.000000
# I1116 17:40:58.049119 140001254688640 run.py:503] {'eval/regularization_loss': 3.48044e-05, 'eval/supervised_loss': nan, 'eval/label_top_1_accuracy': 0.98073834, 'eval/label_top_5_accuracy': 1.0, 'global_step': 37000}
# I1116 17:40:58.196823 140001254688640 run.py:667] Eval complete. Exiting...
